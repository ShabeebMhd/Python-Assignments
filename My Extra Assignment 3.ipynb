# %%
value=int(input("Ender the value: "))
if(value==10):
    print("correct")
# Out:
# Ender the value:  10
# correct

# %%
password=input("Ender Your Password")
if(password=="Hope@123"):
    print("Your password is correct")
# Out:
# Ender Your Password Hope@123
# Your password is correct

# %%
age=int(input("Ender Your Age: "))
if(age<18):
    print("Children")

elif(age<30):
    print("Adult")

elif(age<55):
    print("Citizen")

else:
    print("Senior Citizen")
# Out:
# Ender Your Age:  20
# Adult

# %%
num=int(input("Ender the Number"))
if(num<0):
    print("Negative Number")

else:
    print("Possitive Number")
# Out:
# Ender the Number 1
# Possitive Number

# %%
num=int(input("Enter the Number"))
if(num%5==0):
    print("Number is divisible by 5")

else:
    print("Number is not divisible by 5")
# Out:
# Enter the Number 22
# Number is not divisible by 5
