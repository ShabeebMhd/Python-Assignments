# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name = input('Enter your institute name? : ')
# Out:
# Enter your institute name? :  Hope institute

# %%
name = input('Enter your name: ') 
age = input('Enter your age: ') 
school = input('Enter your school name: ') 
degree = input('Enter your drgree: ')
# Out:
# Enter your name:  Kumar
# Enter your age:  25
# Enter your school name:  PVL Center College
# Enter your drgree:  Bsc Computer Science

# %%
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("add =",num1+num2)
# Out:
# a=  43
# b=  34
# add = 77

# %%
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Sub =",num1-num2)
# Out:
# a=  75
# b=  15
# Sub = 60

# %%
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Mul =",num1*num2)
# Out:
# a=  75
# b=  25
# Mul = 1875

# %%
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Float Div =",num1/num2)
# Out:
# a=  7
# b=  2
# Float Div = 3.5

# %%
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Floor Div =",num1 // num2)
# Out:
# a=  7
# b=  2
# Floor Div = 3

# %%
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Modulo =",num1 % num2)
# Out:
# a=  47
# b=  12
# Modulo = 11

# %%
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Power =",num1 ** num2)
# Out:
# a=  5
# b=  4
# Power = 625
